# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiziferr/Deep_Learning_Workshop/blob/master/02_workshop_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras. callbacks import ModelCheckpoint
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Kaiziferr/Deep_Learning_Workshop/master/workshop_keras_sklearn_introduction/diabetes.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
X = data.drop('Outcome', axis=1)
y = data['Outcome']

# %%
#Define model
model = Sequential()
model.add(Dense(12, input_dim = 8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#Compila el modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #Check Point

# %%
#Checkpoints
filepath = 'checkpoint/weights-improvement-{epoch:02d}-{val_accuracy:02f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit(X,y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.70472, saving model to checkpoint/weights-improvement-01-0.704724.hdf5
#
# Epoch 00002: val_accuracy improved from 0.70472 to 0.75197, saving model to checkpoint/weights-improvement-02-0.751969.hdf5
#
# Epoch 00003: val_accuracy did not improve from 0.75197
#
# Epoch 00004: val_accuracy did not improve from 0.75197
#
# Epoch 00005: val_accuracy did not improve from 0.75197
#
# Epoch 00006: val_accuracy did not improve from 0.75197
#
# Epoch 00007: val_accuracy did not improve from 0.75197
#
# Epoch 00008: val_accuracy did not improve from 0.75197
#
# Epoch 00009: val_accuracy did not improve from 0.75197
#
# Epoch 00010: val_accuracy improved from 0.75197 to 0.75591, saving model to checkpoint/weights-improvement-10-0.755906.hdf5
#
# Epoch 00011: val_accuracy did not improve from 0.75591
#
# Epoch 00012: val_accuracy did not improve from 0.75591
#
# Epoch 00013: val_accuracy did not improve from 0.75591
#
# Epoch 00014: val_accuracy did not improve from 0.75591
#
# Epoch 00015: val_accuracy did not improve from 0.75591
#
# Epoch 00016: val_accuracy did not improve from 0.75591
#
# Epoch 00017: val_accuracy did not improve from 0.75591
#
# Epoch 00018: val_accuracy did not improve from 0.75591
#
# Epoch 00019: val_accuracy improved from 0.75591 to 0.76378, saving model to checkpoint/weights-improvement-19-0.763780.hdf5
#
# Epoch 00020: val_accuracy did not improve from 0.76378
#
# Epoch 00021: val_accuracy did not improve from 0.76378
#
# Epoch 00022: val_accuracy did not improve from 0.76378
#
# Epoch 00023: val_accuracy did not improve from 0.76378
#
# Epoch 00024: val_accuracy did not improve from 0.76378
#
# Epoch 00025: val_accuracy did not improve from 0.76378
#
# Epoch 00026: val_accuracy did not improve from 0.76378
#
# Epoch 00027: val_accuracy did not improve from 0.76378
#
# Epoch 00028: val_accuracy did not improve from 0.76378
#
# Epoch 00029: val_accuracy did not improve from 0.76378
#
# Epoch 00030: val_accuracy improved from 0.76378 to 0.76772, saving model to checkpoint/weights-improvement-30-0.767717.hdf5
#
# Epoch 00031: val_accuracy did not improve from 0.76772
#
# Epoch 00032: val_accuracy did not improve from 0.76772
#
# Epoch 00033: val_accuracy did not improve from 0.76772
#
# Epoch 00034: val_accuracy did not improve from 0.76772
#
# Epoch 00035: val_accuracy did not improve from 0.76772
#
# Epoch 00036: val_accuracy did not improve from 0.76772
#
# Epoch 00037: val_accuracy did not improve from 0.76772
#
# Epoch 00038: val_accuracy did not improve from 0.76772
#
# Epoch 00039: val_accuracy did not improve from 0.76772
#
# Epoch 00040: val_accuracy did not improve from 0.76772
#
# Epoch 00041: val_accuracy did not improve from 0.76772
#
# Epoch 00042: val_accuracy did not improve from 0.76772
#
# Epoch 00043: val_accuracy did not improve from 0.76772
#
# Epoch 00044: val_accuracy did not improve from 0.76772
#
# Epoch 00045: val_accuracy did not improve from 0.76772
#
# Epoch 00046: val_accuracy did not improve from 0.76772
#
# Epoch 00047: val_accuracy did not improve from 0.76772
#
# Epoch 00048: val_accuracy did not improve from 0.76772
#
# Epoch 00049: val_accuracy did not improve from 0.76772
#
# Epoch 00050: val_accuracy did not improve from 0.76772
#
# Epoch 00051: val_accuracy did not improve from 0.76772
#
# Epoch 00052: val_accuracy did not improve from 0.76772
#
# Epoch 00053: val_accuracy did not improve from 0.76772
#
# Epoch 00054: val_accuracy did not improve from 0.76772
#
# Epoch 00055: val_accuracy did not improve from 0.76772
#
# Epoch 00056: val_accuracy did not improve from 0.76772
#
# Epoch 00057: val_accuracy did not improve from 0.76772
#
# Epoch 00058: val_accuracy did not improve from 0.76772
#
# Epoch 00059: val_accuracy did not improve from 0.76772
#
# Epoch 00060: val_accuracy did not improve from 0.76772
#
# Epoch 00061: val_accuracy did not improve from 0.76772
#
# Epoch 00062: val_accuracy did not improve from 0.76772
#
# Epoch 00063: val_accuracy did not improve from 0.76772
#
# Epoch 00064: val_accuracy did not improve from 0.76772
#
# Epoch 00065: val_accuracy did not improve from 0.76772
#
# Epoch 00066: val_accuracy did not improve from 0.76772
#
# Epoch 00067: val_accuracy improved from 0.76772 to 0.77559, saving model to checkpoint/weights-improvement-67-0.775591.hdf5
#
# Epoch 00068: val_accuracy did not improve from 0.77559
#
# Epoch 00069: val_accuracy did not improve from 0.77559
#
# Epoch 00070: val_accuracy did not improve from 0.77559
#
# Epoch 00071: val_accuracy did not improve from 0.77559
#
# Epoch 00072: val_accuracy did not improve from 0.77559
#
# Epoch 00073: val_accuracy did not improve from 0.77559
#
# Epoch 00074: val_accuracy did not improve from 0.77559
#
# Epoch 00075: val_accuracy did not improve from 0.77559
#
# Epoch 00076: val_accuracy did not improve from 0.77559
#
# Epoch 00077: val_accuracy did not improve from 0.77559
#
# Epoch 00078: val_accuracy did not improve from 0.77559
#
# Epoch 00079: val_accuracy did not improve from 0.77559
#
# Epoch 00080: val_accuracy did not improve from 0.77559
#
# Epoch 00081: val_accuracy did not improve from 0.77559
#
# Epoch 00082: val_accuracy did not improve from 0.77559
#
# Epoch 00083: val_accuracy did not improve from 0.77559
#
# Epoch 00084: val_accuracy did not improve from 0.77559
#
# Epoch 00085: val_accuracy did not improve from 0.77559
#
# Epoch 00086: val_accuracy did not improve from 0.77559
#
# Epoch 00087: val_accuracy did not improve from 0.77559
#
# Epoch 00088: val_accuracy did not improve from 0.77559
#
# Epoch 00089: val_accuracy did not improve from 0.77559
#
# Epoch 00090: val_accuracy did not improve from 0.77559
#
# Epoch 00091: val_accuracy did not improve from 0.77559
#
# Epoch 00092: val_accuracy did not improve from 0.77559
#
# Epoch 00093: val_accuracy did not improve from 0.77559
#
# Epoch 00094: val_accuracy did not improve from 0.77559
#
# Epoch 00095: val_accuracy did not improve from 0.77559
#
# Epoch 00096: val_accuracy did not improve from 0.77559
#
# Epoch 00097: val_accuracy did not improve from 0.77559
#
# Epoch 00098: val_accuracy did not improve from 0.77559
#
# Epoch 00099: val_accuracy did not improve from 0.77559
#
# Epoch 00100: val_accuracy did not improve from 0.77559
#
# Epoch 00101: val_accuracy did not improve from 0.77559
#
# Epoch 00102: val_accuracy did not improve from 0.77559
#
# Epoch 00103: val_accuracy did not improve from 0.77559
#
# Epoch 00104: val_accuracy did not improve from 0.77559
#
# Epoch 00105: val_accuracy did not improve from 0.77559
#
# Epoch 00106: val_accuracy did not improve from 0.77559
#
# Epoch 00107: val_accuracy improved from 0.77559 to 0.77953, saving model to checkpoint/weights-improvement-107-0.779528.hdf5
#
# Epoch 00108: val_accuracy did not improve from 0.77953
#
# Epoch 00109: val_accuracy did not improve from 0.77953
#
# Epoch 00110: val_accuracy did not improve from 0.77953
#
# Epoch 00111: val_accuracy did not improve from 0.77953
#
# Epoch 00112: val_accuracy did not improve from 0.77953
#
# Epoch 00113: val_accuracy did not improve from 0.77953
#
# Epoch 00114: val_accuracy did not improve from 0.77953
#
# Epoch 00115: val_accuracy did not improve from 0.77953
#
# Epoch 00116: val_accuracy did not improve from 0.77953
#
# Epoch 00117: val_accuracy did not improve from 0.77953
#
# Epoch 00118: val_accuracy did not improve from 0.77953
#
# Epoch 00119: val_accuracy did not improve from 0.77953
#
# Epoch 00120: val_accuracy did not improve from 0.77953
#
# Epoch 00121: val_accuracy did not improve from 0.77953
#
# Epoch 00122: val_accuracy did not improve from 0.77953
#
# Epoch 00123: val_accuracy did not improve from 0.77953
#
# Epoch 00124: val_accuracy did not improve from 0.77953
#
# Epoch 00125: val_accuracy did not improve from 0.77953
#
# Epoch 00126: val_accuracy did not improve from 0.77953
#
# Epoch 00127: val_accuracy did not improve from 0.77953
#
# Epoch 00128: val_accuracy did not improve from 0.77953
#
# Epoch 00129: val_accuracy improved from 0.77953 to 0.78740, saving model to checkpoint/weights-improvement-129-0.787402.hdf5
#
# Epoch 00130: val_accuracy did not improve from 0.78740
#
# Epoch 00131: val_accuracy did not improve from 0.78740
#
# Epoch 00132: val_accuracy did not improve from 0.78740
#
# Epoch 00133: val_accuracy did not improve from 0.78740
#
# Epoch 00134: val_accuracy did not improve from 0.78740
#
# Epoch 00135: val_accuracy did not improve from 0.78740
#
# Epoch 00136: val_accuracy did not improve from 0.78740
#
# Epoch 00137: val_accuracy did not improve from 0.78740
#
# Epoch 00138: val_accuracy did not improve from 0.78740
#
# Epoch 00139: val_accuracy did not improve from 0.78740
#
# Epoch 00140: val_accuracy did not improve from 0.78740
#
# Epoch 00141: val_accuracy did not improve from 0.78740
#
# Epoch 00142: val_accuracy did not improve from 0.78740
#
# Epoch 00143: val_accuracy did not improve from 0.78740
#
# Epoch 00144: val_accuracy did not improve from 0.78740
#
# Epoch 00145: val_accuracy did not improve from 0.78740
#
# Epoch 00146: val_accuracy did not improve from 0.78740
#
# Epoch 00147: val_accuracy did not improve from 0.78740
#
# Epoch 00148: val_accuracy did not improve from 0.78740
#
# Epoch 00149: val_accuracy did not improve from 0.78740
#
# Epoch 00150: val_accuracy did not improve from 0.78740

# %% [markdown]
# # Cargar el modelo

# %%
modeloC = Sequential()
modeloC.add(Dense(12, input_dim = 8, activation='relu'))
modeloC.add(Dense(8, activation='relu'))
modeloC.add(Dense(1, activation='sigmoid'))

# %%
modeloC.load_weights('/content/checkpoint/weights-improvement-129-0.787402.hdf5')
modeloC.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
