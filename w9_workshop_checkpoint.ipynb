# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiziferr/Deep_Learning_Workshop/blob/master/w9_workshop_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Kaiziferr/Deep_Learning_Workshop/master/workshop_keras_sklearn_introduction/diabetes.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
X = data.drop('Outcome', axis = 1)
y = data['Outcome']

# %%
#Define la estructura del modelo
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#Compila el modelo
model.compile(loss= 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Punto de control

# %%
# Checkpoints
filepath = "checkpoint/weights-improvement-{epoch:02d}-{val_accuracy:0.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
#Entrena el modelo
model.fit(X,y,validation_split=0.33,epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.66929, saving model to checkpoint/weights-improvement-01-0.67.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.66929
#
# Epoch 00003: val_accuracy did not improve from 0.66929
#
# Epoch 00004: val_accuracy did not improve from 0.66929
#
# Epoch 00005: val_accuracy did not improve from 0.66929
#
# Epoch 00006: val_accuracy improved from 0.66929 to 0.68110, saving model to checkpoint/weights-improvement-06-0.68.hdf5
#
# Epoch 00007: val_accuracy did not improve from 0.68110
#
# Epoch 00008: val_accuracy improved from 0.68110 to 0.70079, saving model to checkpoint/weights-improvement-08-0.70.hdf5
#
# Epoch 00009: val_accuracy did not improve from 0.70079
#
# Epoch 00010: val_accuracy did not improve from 0.70079
#
# Epoch 00011: val_accuracy did not improve from 0.70079
#
# Epoch 00012: val_accuracy did not improve from 0.70079
#
# Epoch 00013: val_accuracy did not improve from 0.70079
#
# ...

# %% [markdown]
# # Cargar el modelo

# %%
modeloC = Sequential()
modeloC.add(Dense(12, input_dim=8, activation='relu'))
modeloC.add(Dense(8, activation='relu'))
modeloC.add(Dense(1, activation='sigmoid'))


modeloC.load_weights('/content/checkpoint/weights-improvement-119-0.74.hdf5')

modeloC.compile(loss= 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X = data.drop('Outcome', axis = 1)
y = data['Outcome']


scores = model.evaluate(X,y, verbose=0)
print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 73.31%
